# %%
import yaml
import numpy as np
import matplotlib.pyplot as plt
from lsst.daf.butler import Butler
# %matplotlib inline

# %% [markdown]
# # Check images

# %%
butler_no_diff = Butler('diffraction_test/cwfs_no_diff_g_14/imsimData/')

# %%
butler_w_diff = Butler('diffraction_test/cwfs_w_diff_g_14/imsimData/')

# %%
datasets_no_diff = list(butler_no_diff.registry.queryDatasets('postISRCCD', collections='ts_imsim_1000'))
datasets_w_diff = list(butler_w_diff.registry.queryDatasets('postISRCCD', collections='ts_imsim_1000'))

# %%
fig = plt.figure(figsize=(10, 5))
plt.imshow(butler_no_diff.get(datasets_no_diff[0]).image.array)
plt.xlim((1700, 2300))
plt.ylim((850, 1150))
# Out:
# (850.0, 1150.0)

# %%
fig = plt.figure(figsize=(10, 5))
plt.imshow(butler_w_diff.get(datasets_w_diff[0]).image.array)
plt.xlim((1700, 2300))
plt.ylim((850, 1150))
# Out:
# (850.0, 1150.0)

# %% [markdown]
# # Timing

# %%
no_diff_g_12 = []
for i in range(4):
    with open(f'diffraction_test/cwfs_no_diff_g_12/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_g_12.append(float(line.split(' ')[-2]))

# %%
w_diff_g_12 = []
for i in range(4):
    with open(f'diffraction_test/cwfs_w_diff_g_12/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                w_diff_g_12.append(float(line.split(' ')[-2]))

# %%
no_diff_g_13 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_no_diff_g_13/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_g_13.append(float(line.split(' ')[-2]))

# %%
w_diff_g_13 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_w_diff_g_13/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                w_diff_g_13.append(float(line.split(' ')[-2]))

# %%
no_diff_g_14 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_no_diff_g_14/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_g_14.append(float(line.split(' ')[-2]))

# %%
w_diff_g_14 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_w_diff_g_14/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                w_diff_g_14.append(float(line.split(' ')[-2]))

# %%
w_diff_g_15 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_w_diff_g_15/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                w_diff_g_15.append(float(line.split(' ')[-2]))

# %%
no_diff_g_15 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_no_diff_g_15/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_g_15.append(float(line.split(' ')[-2]))

# %%
plt.errorbar(12, np.mean(w_diff_g_12), yerr=np.std(w_diff_g_12), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(12, np.mean(no_diff_g_12), yerr=np.std(no_diff_g_12), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(13, np.mean(w_diff_g_13), yerr=np.std(w_diff_g_13), capsize=12.0, label='W Diff (LSST_Silicon)', c='C0', markersize=12, marker='.')
plt.errorbar(13, np.mean(no_diff_g_13), yerr=np.std(no_diff_g_13), capsize=12.0, label='No Diff (LSST_Silicon)', c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_g_14), yerr=np.std(w_diff_g_14), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_g_14), yerr=np.std(no_diff_g_14), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_g_15), yerr=np.std(w_diff_g_15), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_g_15), yerr=np.std(no_diff_g_15), capsize=12.0, c='C1', markersize=10, marker='.')
plt.legend()
plt.xlabel('Mag')
plt.ylabel('Log(Seconds Per Image)')
plt.gca().invert_xaxis()
plt.gca().set_yscale('log')

# %%
no_diff_default_stamp_g_14 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_no_diff_default_stamp_g_14/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_default_stamp_g_14.append(float(line.split(' ')[-2]))

# %%
w_diff_default_stamp_g_14 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_w_diff_default_stamp_g_14/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                w_diff_default_stamp_g_14.append(float(line.split(' ')[-2]))

# %%
w_diff_default_stamp_g_15 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_w_diff_default_stamp_g_15/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                w_diff_default_stamp_g_15.append(float(line.split(' ')[-2]))

# %%
no_diff_default_stamp_g_15 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_no_diff_default_stamp_g_15/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_default_stamp_g_15.append(float(line.split(' ')[-2]))

# %%
no_diff_default_stamp_g_13 = []
for i in range(10):
    with open(f'diffraction_test/cwfs_no_diff_default_stamp_g_13/iter{i}/pert/imsim_output.log', 'r') as f:
        for line in f.readlines():
            if line.endswith('sec\n'):
                #print(line.split(' '))
                no_diff_default_stamp_g_13.append(float(line.split(' ')[-2]))

# %%
plt.errorbar(12, np.mean(w_diff_g_12), yerr=np.std(w_diff_g_12), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(12, np.mean(no_diff_g_12), yerr=np.std(no_diff_g_12), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(13, np.mean(w_diff_g_13), yerr=np.std(w_diff_g_13), capsize=12.0, label='W Diff (LSST_Silicon)', c='C0', markersize=12, marker='.')
plt.errorbar(13, np.mean(no_diff_g_13), yerr=np.std(no_diff_g_13), capsize=12.0, label='No Diff (LSST_Silicon)', c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_g_14), yerr=np.std(w_diff_g_14), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_g_14), yerr=np.std(no_diff_g_14), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_g_15), yerr=np.std(w_diff_g_15), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_g_15), yerr=np.std(no_diff_g_15), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_default_stamp_g_14), yerr=np.std(w_diff_default_stamp_g_14), capsize=12.0, label='W Diff (Default Stamp)', c='C2', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_default_stamp_g_14), yerr=np.std(no_diff_default_stamp_g_14), capsize=12.0, label='No Diff (Default Stamp)', c='C3', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_default_stamp_g_15), yerr=np.std(w_diff_default_stamp_g_15), capsize=12.0, c='C2', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_default_stamp_g_15), yerr=np.std(no_diff_default_stamp_g_15), capsize=12.0, c='C3', markersize=10, marker='.')
plt.errorbar(13, np.mean(no_diff_default_stamp_g_13), yerr=np.std(no_diff_default_stamp_g_13), capsize=12.0, c='C3', markersize=10, marker='.')
plt.legend()
plt.xlabel('Mag')
plt.ylabel('Log(Seconds Per Image)')
plt.gca().invert_xaxis()
plt.gca().set_yscale('log')

# %%
plt.scatter(12, np.mean(w_diff_g_12), marker='o', s=160, c='C0')
plt.scatter(12, np.mean(no_diff_g_12), marker='x', lw=3, s=160,  c='C1')
plt.scatter(13, np.mean(w_diff_g_13), marker='o', s=160, label='W Diff (LSST_Silicon)', c='C0')
plt.scatter(13, np.mean(no_diff_g_13), marker='x',  s=160, lw=3, label='No Diff (LSST_Silicon)', c='C1')
plt.scatter(14, np.mean(w_diff_g_14), marker='o', s=160, c='C0')
plt.scatter(14, np.mean(no_diff_g_14), marker='x',  s=160,lw=3,  c='C1')
plt.scatter(15, np.mean(w_diff_g_15), marker='o', s=160, c='C0')
plt.scatter(15, np.mean(no_diff_g_15), marker='x',  s=160, lw=3, c='C1')
plt.scatter(14, np.mean(w_diff_default_stamp_g_14), marker='o',  s=160, label='W Diff (Default Stamp)', c='C2')
plt.scatter(14, np.mean(no_diff_default_stamp_g_14), marker='x',  lw=3, s=160,  label='No Diff (Default Stamp)', c='C3')
plt.scatter(15, np.mean(w_diff_default_stamp_g_15), marker='o', s=160, c='C2')
plt.scatter(15, np.mean(no_diff_default_stamp_g_15), marker='x', lw=3,  s=160, c='C3')
plt.scatter(13, np.mean(no_diff_default_stamp_g_13), marker='x',  lw=3, s=160, c='C3')
plt.legend()
plt.xlabel('Mag')
plt.ylabel('Log(Seconds Per Image)')
plt.gca().invert_xaxis()
plt.gca().set_yscale('log')

# %%
plt.errorbar(12, np.mean(w_diff_g_12), yerr=np.std(w_diff_g_12), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(12, np.mean(no_diff_g_12), yerr=np.std(no_diff_g_12), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(13, np.mean(w_diff_g_13), yerr=np.std(w_diff_g_13), capsize=12.0, label='W Diff (LSST_Silicon)', c='C0', markersize=12, marker='.')
plt.errorbar(13, np.mean(no_diff_g_13), yerr=np.std(no_diff_g_13), capsize=12.0, label='No Diff (LSST_Silicon)', c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_g_14), yerr=np.std(w_diff_g_14), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_g_14), yerr=np.std(no_diff_g_14), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_g_15), yerr=np.std(w_diff_g_15), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_g_15), yerr=np.std(no_diff_g_15), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_default_stamp_g_14), yerr=np.std(w_diff_default_stamp_g_14), capsize=12.0, label='W Diff (Default Stamp)', c='C2', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_default_stamp_g_14), yerr=np.std(no_diff_default_stamp_g_14), capsize=12.0, label='No Diff (Default Stamp)', c='C3', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_default_stamp_g_15), yerr=np.std(w_diff_default_stamp_g_15), capsize=12.0, c='C2', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_default_stamp_g_15), yerr=np.std(no_diff_default_stamp_g_15), capsize=12.0, c='C3', markersize=10, marker='.')
plt.errorbar(13, np.mean(no_diff_default_stamp_g_13), yerr=np.std(no_diff_default_stamp_g_13), capsize=12.0, c='C3', markersize=10, marker='.')
plt.legend()
plt.xlabel('Mag')
plt.ylabel('Seconds Per Image')
plt.gca().invert_xaxis()

# %%
plt.errorbar(13, np.mean(w_diff_g_13), yerr=np.std(w_diff_g_13), capsize=12.0, label='W Diff (LSST_Silicon)', c='C0', markersize=12, marker='.')
plt.errorbar(13, np.mean(no_diff_g_13), yerr=np.std(no_diff_g_13), capsize=12.0, label='No Diff (LSST_Silicon)', c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_g_14), yerr=np.std(w_diff_g_14), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_g_14), yerr=np.std(no_diff_g_14), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_g_15), yerr=np.std(w_diff_g_15), capsize=12.0, c='C0', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_g_15), yerr=np.std(no_diff_g_15), capsize=12.0, c='C1', markersize=10, marker='.')
plt.errorbar(14, np.mean(w_diff_default_stamp_g_14), yerr=np.std(w_diff_default_stamp_g_14), capsize=12.0, label='W Diff (Default Stamp)', c='C2', markersize=12, marker='.')
plt.errorbar(14, np.mean(no_diff_default_stamp_g_14), yerr=np.std(no_diff_default_stamp_g_14), capsize=12.0, label='No Diff (Default Stamp)', c='C3', markersize=10, marker='.')
plt.errorbar(15, np.mean(w_diff_default_stamp_g_15), yerr=np.std(w_diff_default_stamp_g_15), capsize=12.0, c='C2', markersize=12, marker='.')
plt.errorbar(15, np.mean(no_diff_default_stamp_g_15), yerr=np.std(no_diff_default_stamp_g_15), capsize=12.0, c='C3', markersize=10, marker='.')
plt.errorbar(13, np.mean(no_diff_default_stamp_g_13), yerr=np.std(no_diff_default_stamp_g_13), capsize=12.0, c='C3', markersize=10, marker='.')
plt.legend()
plt.xlabel('Mag')
plt.ylabel('Seconds Per Image')
plt.gca().invert_xaxis()

# %%
np.mean(no_diff_g_15), np.mean(w_diff_g_15), np.mean(no_diff_default_stamp_g_15), np.mean(w_diff_default_stamp_g_15)
# Out:
# (183.18646167058824, 219.05219631952662, 219.02831002247189, 226.0979)

# %% [markdown]
# # Convergence

# %%
pssn_no_diff_g_12 = []
fwhm_no_diff_g_12 = []
for i in range(4):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_no_diff_g_12/iter{i}/img/PSSN.txt')
    pssn_no_diff_g_12.append(pssn_file[0])
    fwhm_no_diff_g_12.append(pssn_file[1])
pssn_no_diff_g_12 = np.array(pssn_no_diff_g_12)
fwhm_no_diff_g_12 = np.array(fwhm_no_diff_g_12)

# %%
pssn_no_diff_g_13 = []
fwhm_no_diff_g_13 = []
for i in range(10):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_no_diff_g_13/iter{i}/img/PSSN.txt')
    pssn_no_diff_g_13.append(pssn_file[0])
    fwhm_no_diff_g_13.append(pssn_file[1])
pssn_no_diff_g_13 = np.array(pssn_no_diff_g_13)
fwhm_no_diff_g_13 = np.array(fwhm_no_diff_g_13)

# %%
pssn_no_diff_g_14 = []
fwhm_no_diff_g_14 = []
for i in range(10):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_no_diff_g_14/iter{i}/img/PSSN.txt')
    pssn_no_diff_g_14.append(pssn_file[0])
    fwhm_no_diff_g_14.append(pssn_file[1])
pssn_no_diff_g_14 = np.array(pssn_no_diff_g_14)
fwhm_no_diff_g_14 = np.array(fwhm_no_diff_g_14)

# %%
pssn_no_diff_g_15 = []
fwhm_no_diff_g_15 = []
for i in range(10):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_no_diff_g_15/iter{i}/img/PSSN.txt')
    pssn_no_diff_g_15.append(pssn_file[0])
    fwhm_no_diff_g_15.append(pssn_file[1])
pssn_no_diff_g_15 = np.array(pssn_no_diff_g_15)
fwhm_no_diff_g_15 = np.array(fwhm_no_diff_g_15)

# %%
pssn_w_diff_g_12 = []
fwhm_w_diff_g_12 = []
for i in range(4):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_w_diff_g_12/iter{i}/img/PSSN.txt')
    pssn_w_diff_g_12.append(pssn_file[0])
    fwhm_w_diff_g_12.append(pssn_file[1])
pssn_w_diff_g_12 = np.array(pssn_w_diff_g_12)
fwhm_w_diff_g_12 = np.array(fwhm_w_diff_g_12)

# %%
pssn_w_diff_g_13 = []
fwhm_w_diff_g_13 = []
for i in range(10):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_w_diff_g_13/iter{i}/img/PSSN.txt')
    pssn_w_diff_g_13.append(pssn_file[0])
    fwhm_w_diff_g_13.append(pssn_file[1])
pssn_w_diff_g_13 = np.array(pssn_w_diff_g_13)
fwhm_w_diff_g_13 = np.array(fwhm_w_diff_g_13)

# %%
pssn_w_diff_g_14 = []
fwhm_w_diff_g_14 = []
for i in range(10):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_w_diff_g_14/iter{i}/img/PSSN.txt')
    pssn_w_diff_g_14.append(pssn_file[0])
    fwhm_w_diff_g_14.append(pssn_file[1])
pssn_w_diff_g_14 = np.array(pssn_w_diff_g_14)
fwhm_w_diff_g_14 = np.array(fwhm_w_diff_g_14)

# %%
pssn_w_diff_g_15 = []
fwhm_w_diff_g_15 = []
for i in range(10):
    pssn_file = np.loadtxt(f'diffraction_test/cwfs_w_diff_g_15/iter{i}/img/PSSN.txt')
    pssn_w_diff_g_15.append(pssn_file[0])
    fwhm_w_diff_g_15.append(pssn_file[1])
pssn_w_diff_g_15 = np.array(pssn_w_diff_g_15)
fwhm_w_diff_g_15 = np.array(fwhm_w_diff_g_15)

# %%
plt.plot(np.arange(1, 5), fwhm_no_diff_g_12[:, 4], label='No diffraction')
plt.plot(np.arange(1, 5), fwhm_w_diff_g_12[:, 4], label='With diffraction')
plt.title('g_mag = 12, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')
# Out:
# Text(0, 0.5, 'FWHM_eff (arcseconds)')

# %%
plt.plot(np.arange(1, 11), fwhm_no_diff_g_13[:, 4], label='No diffraction')
plt.plot(np.arange(1, 11), fwhm_w_diff_g_13[:, 4], label='With diffraction')
plt.title('g_mag = 13, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')
# Out:
# Text(0, 0.5, 'FWHM_eff (arcseconds)')

# %%
plt.plot(np.arange(1, 11), fwhm_no_diff_g_14[:, 4], label='No diffraction')
plt.plot(np.arange(1, 11), fwhm_w_diff_g_14[:, 4], label='With diffraction')
plt.title('g_mag = 14, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')
# Out:
# Text(0, 0.5, 'FWHM_eff (arcseconds)')

# %%
plt.plot(np.arange(1, 11), fwhm_no_diff_g_15[:, 4], label='No diffraction')
plt.plot(np.arange(1, 11), fwhm_w_diff_g_15[:, 4], label='With diffraction')
plt.title('g_mag = 15, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')
# Out:
# Text(0, 0.5, 'FWHM_eff (arcseconds)')

# %%
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(2,2,1)
plt.plot(np.arange(1, 5), fwhm_no_diff_g_12[:, 4], label='No diffraction')
plt.plot(np.arange(1, 5), fwhm_w_diff_g_12[:, 4], label='With diffraction')
plt.title('g_mag = 12, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')

fig.add_subplot(2,2,2)
plt.plot(np.arange(1, 11), fwhm_no_diff_g_13[:, 4], label='No diffraction')
plt.plot(np.arange(1, 11), fwhm_w_diff_g_13[:, 4], label='With diffraction')
plt.title('g_mag = 13, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')

fig.add_subplot(2,2,3)
plt.plot(np.arange(1, 11), fwhm_no_diff_g_14[:, 4], label='No diffraction')
plt.plot(np.arange(1, 11), fwhm_w_diff_g_14[:, 4], label='With diffraction')
plt.title('g_mag = 14, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')

fig.add_subplot(2,2,4)
plt.plot(np.arange(1, 11), fwhm_no_diff_g_15[:, 4], label='No diffraction')
plt.plot(np.arange(1, 11), fwhm_w_diff_g_15[:, 4], label='With diffraction')
plt.title('g_mag = 15, No atm, No sky brightness')
plt.legend()
plt.xlabel('Iteration')
plt.ylabel('FWHM_eff (arcseconds)')

plt.tight_layout()

# %% [markdown]
# # OPD vs WEP Comparison

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_no_diff_g_14/iter{i}/img/opd.zer', 'r') as f:
    opd_no_diff_g_14 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_no_diff_g_15/iter{i}/img/opd.zer', 'r') as f:
    opd_no_diff_g_15 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_w_diff_g_14/iter{i}/img/opd.zer', 'r') as f:
    opd_w_diff_g_14 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_w_diff_g_15/iter{i}/img/opd.zer', 'r') as f:
    opd_w_diff_g_15 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_no_diff_g_14/iter{i}/img/wfs.zer', 'r') as f:
    wfs_no_diff_g_14 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_no_diff_g_15/iter{i}/img/wfs.zer', 'r') as f:
    wfs_no_diff_g_15 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_w_diff_g_14/iter{i}/img/wfs.zer', 'r') as f:
    wfs_w_diff_g_14 = yaml.safe_load(f)

# %%
# for i in range(10):
i = 0
with open(f'diffraction_test/cwfs_w_diff_g_15/iter{i}/img/wfs.zer', 'r') as f:
    wfs_w_diff_g_15 = yaml.safe_load(f)

# %%
det_num = [191, 195, 199, 203]
fig = plt.figure(figsize=(12,8))
for idx, det in enumerate(det_num):
    fig.add_subplot(2,2,idx+1)
    plt.plot(np.arange(4,23), np.loadtxt(opd_no_diff_g_14[det])/1e3, label='OPD')
    plt.plot(np.arange(4,23), np.loadtxt(wfs_no_diff_g_14[det]), label='WEP, No Diff')
    plt.plot(np.arange(4,23), np.loadtxt(wfs_w_diff_g_14[det]), label='WEP, W Diff')
    plt.title(f'Detector {det}')
    plt.xlabel('Zernike Coeff')
    plt.xticks(np.arange(4, 23, 4))
    plt.ylabel('Microns')
    plt.legend()
plt.tight_layout()

# %%
det_num = [191, 195, 199, 203]
fig = plt.figure(figsize=(12,8))
for idx, det in enumerate(det_num):
    fig.add_subplot(2,2,idx+1)
    plt.plot(np.arange(4,23), np.loadtxt(opd_no_diff_g_15[det])/1e3, label='OPD')
    plt.plot(np.arange(4,23), np.loadtxt(wfs_no_diff_g_15[det]), label='WEP, No Diff')
    plt.plot(np.arange(4,23), np.loadtxt(wfs_w_diff_g_15[det]), label='WEP, W Diff')
    plt.title(f'Detector {det}')
    plt.xlabel('Zernike Coeff')
    plt.xticks(np.arange(4, 23, 4))
    plt.ylabel('Microns')
    plt.legend()
plt.tight_layout()
